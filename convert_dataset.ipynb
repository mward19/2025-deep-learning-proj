# %%
import pandas as pd

import torch
from torchvision import transforms

import os
from tqdm.notebook import tqdm

from data import load_full_tomogram_array, get_dataframes

# %%
train_set, val_set = get_dataframes()

# %%
train_set.head()
# Out:
#      row_id      tomo_id  Motor axis 0  Motor axis 1  Motor axis 2  \
# 135     135  tomo_2daaee         185.0         596.0         860.0
# 545     545  tomo_bbe766         195.0         855.0         288.0
# 497     497  tomo_ae347a         206.0         788.0         581.0
# 340     340  tomo_736dfa          -1.0          -1.0          -1.0
# 165     165  tomo_37dd38         162.0         100.0         662.0
#
#      Array shape (axis 0)  Array shape (axis 1)  Array shape (axis 2)  \
# 135                   500                   924                   956
# 545                   300                   959                   928
# 497                   500                   924                   956
# 340                   800                   927                   959
# 165                   500                   924                   956
#
#      Voxel spacing  Number of motors
# 135           19.7                 4
# 545           15.6                 1
# ...

# %%
for tomo_id in tqdm(train_set['tomo_id']):
    print(tomo_id)
    load_full_tomogram_array(tomo_id, train=True)
# Out:
#   0%|          | 0/589 [00:00<?, ?it/s]
# tomo_2daaee
# tomo_bbe766
# tomo_ae347a
# tomo_736dfa
# tomo_37dd38
# tomo_9aee96
# tomo_2daaee
# tomo_417e5f
# tomo_00e463
# tomo_6df2d6
# tomo_1b82d1
# tomo_935f8a
# tomo_d23087
# tomo_305c97
# tomo_4f5a7b
# tomo_754447
# tomo_2c9da1
# tomo_6a6a3b
# tomo_813916
# tomo_eb26ee
# tomo_0eb41e
# tomo_23ce49
# tomo_9a7701
# tomo_13973d
# tomo_3b8291
# tomo_49725c
# tomo_db4517
# tomo_bb9df3
# tomo_081a2d
# tomo_4c1ca8
# tomo_e5ac94
# tomo_640a74
# tomo_8174f5
# tomo_651ec2
# tomo_24795a
# tomo_1da097
# tomo_12f896
# tomo_8f4d60
# tomo_cad74b
# tomo_ef1a1a
# tomo_f672c0
# tomo_ea3f3a
# tomo_ff505c
# tomo_2dcd5c
# tomo_6607ec
# tomo_643b20
# tomo_05b39c
# tomo_b9de3e
# tomo_57592d
# tomo_e0739f
# tomo_ab30af
# tomo_1da0da
# tomo_161683
# tomo_4e478f
# tomo_98d455
# tomo_08bf73
# tomo_d916dc
# tomo_4b59a2
# tomo_61e947
# tomo_8554af
# tomo_3b83c7
# tomo_acadd7
# tomo_bcb115
# tomo_dd36c9
# tomo_7ca7c0
# tomo_d634b7
# tomo_a75c98
# tomo_8acc4b
# ...
